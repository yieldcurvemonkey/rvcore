# %%
import sys
sys.path.append("../")

# %%
import QuantLib as ql
from datetime import datetime
from sqlalchemy import create_engine

from core.Products.Cash import Cash 
from core.utils.ql_utils import datetime_to_ql_date

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
plt.style.use('ggplot')
params = {'legend.fontsize': 'x-large',
        'figure.figsize': (12, 8),
        'axes.labelsize': 'x-large',
        'axes.titlesize':'x-large',
        'xtick.labelsize':'x-large',
        'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

import nest_asyncio
nest_asyncio.apply()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # `Cash` Product
# - Basic Example: Par Curve Model is a [LOESS Spline](https://en.wikipedia.org/wiki/Local_regression) fit on EOD YTMs

# %%
usts = Cash(
    data_source=create_engine(f"postgresql://postgres:password@localhost:5432/rvcore_fedinvest_cusip_set"),
    par_curve_model_key="general_spliner",
    par_curve_model_kwags_ex_cusip_set={
        "custom_filter_func": lambda df: df,
		"spliner_y_col": "eod_ytm",
        "GeneralCurveInterpolator_func": "loess_interpolation",
        "GeneralCurveInterpolator_kwags": {
            "frac": 0.075,
            "it": 5,
            "delta": 0,
            "return_func": True,
        },
    },
    curve="USD",
    error_verbose=True,
)

# %% [markdown]
# ## Plotting CUSIP YTMs + Par Curve Model

# %%
usts.plot_all_cusips(date=datetime(2025, 4, 7))
# Out:
# BOOTSTRAPPING HISTORICAL CASH CURVE...: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]

# %% [markdown]
# ## Plotting `CUSIP` Timeseries
